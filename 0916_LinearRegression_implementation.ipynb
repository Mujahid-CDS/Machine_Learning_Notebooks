# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:\\Users\\Shayeda\\Documents\\DATAMITES CDS\\Datasets\\mtcars.csv')
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df.isnull().sum()
# Out:
# model    0
# mpg      0
# cyl      0
# disp     0
# hp       0
# drat     0
# wt       0
# qsec     0
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %%
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %% [markdown]
# # Skipping EDA for time being

# %% [markdown]
# # Linearity

# %%
df.corr()
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659  0.418684
# cyl  -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496 -0.591242
# disp -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.433698
# hp   -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748 -0.708223
# drat  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.091205
# wt   -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000 -0.174716
# qsec  0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.744535
# am    0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.229861
# gear  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.212682
# carb -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.656249
#
#             vs        am      gear      carb
# ...

# %%
a=df.corr().mpg

# %%
a
# Out:
# mpg     1.000000
# cyl    -0.852162
# disp   -0.847551
# hp     -0.776168
# drat    0.681172
# wt     -0.867659
# qsec    0.418684
# vs      0.664039
# am      0.599832
# gear    0.480285
# carb   -0.550925
# Name: mpg, dtype: float64

# %%
df_temp=df.loc[:,['cyl','disp','hp','wt','mpg']]

# %%
df_temp.head()
# Out:
#    cyl   disp   hp     wt   mpg
# 0    6  160.0  110  2.620  21.0
# 1    6  160.0  110  2.875  21.0
# 2    4  108.0   93  2.320  22.8
# 3    6  258.0  110  3.215  21.4
# 4    8  360.0  175  3.440  18.7

# %%
from scipy import stats

# %%
print('Normality of cyl')
print('skewness',stats.skew(df_temp.cyl))
print('kurtosis',stats.kurtosis(df_temp.cyl))
# Out:
# Normality of cyl
# skewness -0.18312865234479678
# kurtosis -1.6809684168130405

# %%
print('Normality of disp')
print('skewness',stats.skew(df_temp.disp))
print('kurtosis',stats.kurtosis(df_temp.disp))
# Out:
# Normality of disp
# skewness 0.40027244847286664
# kurtosis -1.0896826570135087

# %%
print('Normality of hp')
print('skewness',stats.skew(df_temp.hp))
print('kurtosis',stats.kurtosis(df_temp.hp))
# Out:
# Normality of hp
# skewness 0.7614356361333623
# kurtosis 0.05223272840399584

# %%
print('Normality of wt')
print('skewness',stats.skew(df_temp.wt))
print('kurtosis',stats.kurtosis(df_temp.wt))
# Out:
# Normality of wt
# skewness 0.44378553550607647
# kurtosis 0.1724705401587352

# %%
print('Normality of mpg')
print('skewness',stats.skew(df_temp.mpg))
print('kurtosis',stats.kurtosis(df_temp.mpg))
# Out:
# Normality of mpg
# skewness 0.6404398640318834
# kurtosis -0.20053320971549793

# %% [markdown]
# # Collinearity

# %%
df_temp.drop('cyl', axis=1, inplace=True)

# %%
df_temp.head(3)
# Out:
#     disp   hp     wt   mpg
# 0  160.0  110  2.620  21.0
# 1  160.0  110  2.875  21.0
# 2  108.0   93  2.320  22.8

# %%
df_temp.corr()
# Out:
#           disp        hp        wt       mpg
# disp  1.000000  0.790949  0.887980 -0.847551
# hp    0.790949  1.000000  0.658748 -0.776168
# wt    0.887980  0.658748  1.000000 -0.867659
# mpg  -0.847551 -0.776168 -0.867659  1.000000

# %% [markdown]
# - disp, ht and wt are highly correlated, we remove any two of them

# %%
import seaborn as sb

# %%
sb.heatmap(df_temp.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
X=df_temp.iloc[:,:-1]
Y=df_temp.mpg

# %%
X.head()
# Out:
#     disp   hp     wt
# 0  160.0  110  2.620
# 1  160.0  110  2.875
# 2  108.0   93  2.320
# 3  258.0  110  3.215
# 4  360.0  175  3.440

# %%
Y.head()
# Out:
# 0    21.0
# 1    21.0
# 2    22.8
# 3    21.4
# 4    18.7
# Name: mpg, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test= train_test_split(X,Y, test_size=0.2)

# %%
X_train.shape
# Out:
# (25, 3)

# %%
X_test.shape
# Out:
# (7, 3)

# %%
Y_test.shape
# Out:
# (7,)

# %%
Y_train.shape
# Out:
# (25,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
X.head()
# Out:
#     disp   hp     wt
# 0  160.0  110  2.620
# 1  160.0  110  2.875
# 2  108.0   93  2.320
# 3  258.0  110  3.215
# 4  360.0  175  3.440

# %%
model.predict([[200,50,0.5],[50,400,2.5]])
# Out:
# array([33.45684771, 15.62086963])

# %%
Y_predict=model.predict(X_test)

# %%
Y_test
# Out:
# 6     14.3
# 10    17.8
# 11    16.4
# 0     21.0
# 5     18.1
# 20    21.5
# 26    26.0
# Name: mpg, dtype: float64

# %%
from sklearn.metrics import r2_score

# %%
r2_score(Y_test,Y_predict)
# Out:
# 0.5192565513344896
